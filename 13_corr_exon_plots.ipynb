# %%
# conda activate anndata

import os
import re
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad
from scipy import sparse
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

pd.set_option('display.max_columns', None)

# %%
# def _col_idx_for(df, stat):
#     return df.columns.str.contains(stat)

def _safe(name):
    # simple filename sanitizer
    return re.sub(r'[^A-Za-z0-9_.-]+', '_', str(name))

def _barplot_colors(ctypes, working_ctype):
    colors = ["tab:blue"] * len(ctypes)
    idx = pd.Index(ctypes).get_indexer([working_ctype])[0]
    colors[idx] = "tab:red"
    return colors

def _flatten_1d(x):
    if sparse.issparse(x):   # AnnData/sparse safe
        return x.toarray().ravel()
    return np.asarray(x, dtype=float).ravel()

def plot_barplot_by_cell_type(means, errs, ctypes, working_ctype, title, ylabel, show=True):
    # mean_cols = _col_idx_for(df, "mean")
    # se_cols  = _col_idx_for(df, "SE")
    # means = df.loc[exon, mean_cols].astype(float).values
    # errs = df.loc[exon, se_cols].astype(float).values * 2.0
   
    means = np.asarray(means)
    errs = np.asarray(errs) * 2.0 
    
    colors = _barplot_colors(ctypes, working_ctype)
    x = np.arange(len(ctypes))
    fig, ax = plt.subplots()
    ax.bar(x, means, yerr=errs, capsize=3, color=colors)
    ax.set_xticks(x); ax.set_xticklabels(ctypes, rotation=45, ha="right")
    ax.set_ylabel(ylabel); ax.set_title(title)
    fig.tight_layout()
    if show:
        plt.show()
    return fig

def plot_ME_vs_PSI(mod_eig, exon_psi, title, show=True):
    fig, ax = plt.subplots()
    ax.scatter(mod_eig, exon_psi, s=18)
    ax.set_xlabel("Module eigengene")
    ax.set_ylabel("Exon PSI")
    ax.set_title(title)
    plt.tight_layout()
    if show:
        plt.show()
    return fig

def violin_with_points(values_by_ct, ctypes, focus=None,
                       base_fc='tab:blue', highlight_fc='tab:red',
                       ylabel="Value", title=None,
                       jitter=0.08, point_size=8, point_alpha=0.35,
                       max_points_per_ct=None, seed=0, violin_alpha=0.5,
                       show=False):                         # <- default False when saving
    rng = np.random.default_rng(seed)
    pos = np.arange(1, len(ctypes)+1)

    fig, ax = plt.subplots()                                # <- create fig
    vp = ax.violinplot(values_by_ct, positions=pos, showmeans=True, showextrema=True)

    # color violins (no outlines)
    for i, b in enumerate(vp['bodies']):
        col = highlight_fc if (focus is not None and ctypes[i] == focus) else base_fc
        b.set_facecolor(col)
        b.set_edgecolor('none')
        b.set_alpha(violin_alpha)
    for k in ('cmeans','cmins','cmaxes','cbars','cmedians'):
        if k in vp: vp[k].set_visible(False)

    # jitter points
    for i, v in enumerate(values_by_ct, start=1):
        v = np.asarray(v, float)
        v = v[np.isfinite(v)]
        if v.size == 0: continue
        if max_points_per_ct and v.size > max_points_per_ct:
            v = v[rng.choice(v.size, size=max_points_per_ct, replace=False)]
        x = i + (rng.random(v.size) - 0.5) * 2 * jitter
        col = highlight_fc if (focus is not None and ctypes[i-1] == focus) else base_fc
        ax.scatter(x, v, s=point_size, alpha=point_alpha, color=col, edgecolors='none', rasterized=True)

    ax.set_xticks(pos); ax.set_xticklabels(ctypes, rotation=45, ha='right')
    ax.set_ylabel(ylabel); 
    if title: ax.set_title(title)
    fig.tight_layout()

    if show:
        plt.show()

    return fig

# %%
pseudobulk_str = "20pcntCells_30pcntVar_200samples"
psi_data = f"SyntheticDataset1_{pseudobulk_str}_SJ_pseudobulk_min_observed0.05_minPsi0.05_PSI"
merge_param = "0.9"
pdf_path_prefix = f"figures/tasic_2018_ALM_STAR_{psi_data}"
psi = pd.read_csv(f"data/tasic_2018_ALM_STAR_{psi_data}.csv", index_col=0)
corr_df = pd.read_csv(f"data/tasic_2018_ALM_STAR_{psi_data}_exon_corr.csv", index_col=0)
top_qval_mods_df = pd.read_csv(f"data/tasic_2018_ALM_STAR_donor_cell_type_pseudobulk_pairwise_DE_genes_dream_{pseudobulk_str}_log2_pseudobulk_PosBC_top_Qval_modules.csv")

# %%
# pseudobulk_str = "25pcntCells_100SD_200samples"
# psi_data = f"SyntheticDataset1_{pseudobulk_str}_SJ_pseudobulk_min_observed0.05_PSI"
# merge_param = "0.9"
# pdf_path_prefix = f"figures/tasic_2018_ALM_STAR_{psi_data}"
# psi = pd.read_csv(f"data/tasic_2018_ALM_STAR_{psi_data}.csv", index_col=0)
# corr_df = pd.read_csv(f"data/tasic_2018_ALM_STAR_{psi_data}_exon_corr.csv", index_col=0)
# top_qval_mods_df = pd.read_csv(f"data/tasic_2018_ALM_STAR_donor_cell_type_pseudobulk_pairwise_DE_genes_dream_{pseudobulk_str}_log2_pseudobulk_PosBC_top_Qval_modules.csv")

# %%
top_qval_mods_df.index = top_qval_mods_df['Cell_type']
gene_exon_df = corr_df['Gene']

# %%
# Load single-cell PSI data
sdata = ad.read_h5ad("data/tasic_2018_ALM_STAR_SJ_counts_annotated_PSI.hd5")
# Load single-cell gene expression data
adata = ad.read_h5ad("data/tasic_2018_ALM_STAR_model/tasic_2018_ALM_STAR_gene_counts_scVI.h5ad")

# %%
adata.obs['cell_subclass'] = adata.obs['cell_subclass'].astype(str).str.replace("/", "_", regex=False).str.replace(" ", "_", regex=False)
sdata.obs['cell_subclass'] = sdata.obs['cell_subclass'].astype(str).str.replace("/", "_", regex=False).str.replace(" ", "_", regex=False)

# %%
# Work with full gene space
adata_raw = adata.raw.to_adata()
adata_raw.X = adata_raw.X.toarray()

# %%
ctypes = corr_df.columns[1:]

# %%
top_n = 15
ascending = False

for w_ctype in ctypes:
    print(w_ctype)
    outdir = f"figures/{w_ctype}/{pseudobulk_str}/{merge_param}"
    os.makedirs(outdir, exist_ok=True)

    row = top_qval_mods_df.loc[w_ctype]
    mod_df = pd.read_csv(row['ME_path'])
    mod_eig_df = mod_df.set_index("Sample")[row['Module']]
    mod_eig = pd.to_numeric(mod_eig_df, errors="coerce")

    # Get mean expression of cell type exon/gene in each cell type

    corr_df = corr_df.sort_values(w_ctype, ascending=ascending)
    top_exons = corr_df[w_ctype].index.tolist()[:top_n]

    cols = [f"{ct}_{stat}" for ct in ctypes for stat in ("mean", "SE")]
    ctype_psi_df = pd.DataFrame(columns=cols, index=top_exons) 
    ctype_expr_df = pd.DataFrame(columns=cols, index=top_exons)

    for exon in top_exons:
        exon_mask = sdata.var_names.isin([exon])
        sdata_sub = sdata[:, exon_mask].copy()
        gene_mask = adata_raw.var_names.isin([gene_exon_df.loc[exon]])
        adata_sub = adata_raw[:, gene_mask].copy()
        
        psi_vals_by_ct = []
        expr_vals_by_ct = []
        mean_psi_by_ct = [] 
        mean_psi_se_by_ct = []
        mean_expr_by_ct = []
        mean_expr_se_by_ct = []

        for ct in ctypes:
            cell_mask = adata_sub.obs['cell_subclass'] == ct
            n = np.sum(cell_mask)
            psi_per_cell = _flatten_1d(sdata_sub.X[cell_mask, :])
            expr_per_cell = _flatten_1d(adata_sub.X[cell_mask, :])

            psi_vals_by_ct.append(psi_per_cell)
            expr_vals_by_ct.append(np.log1p(expr_per_cell))

            mean_psi_by_ct.append(np.mean(psi_per_cell))
            mean_psi_se_by_ct.append(np.sqrt(np.var(psi_per_cell) / n))

            mean_expr = np.mean(adata_raw.X[cell_mask, :]) 
            mean_expr_by_ct.append(np.mean(expr_per_cell))
            mean_expr_se_by_ct.append(np.sqrt(np.var(expr_per_cell) / n) / mean_expr)

        corr = round(corr_df.loc[exon, w_ctype], 2)
        gene = gene_exon_df.loc[exon]
        exon_psi = psi.loc[exon]
        exon_label = ''.join(str(exon).split("_")[1:])
        pdf_path = f"{outdir}/{_safe(w_ctype)}_{_safe(gene)}_{_safe(exon_label)}_ascending{ascending}.pdf"

        with PdfPages(pdf_path) as pdf:
            fig = plot_barplot_by_cell_type(mean_psi_by_ct, mean_psi_se_by_ct, 
                                            ctypes, w_ctype,
                                            title=f"PSI for {gene} {exon_label} exon",
                                            ylabel="Mean PSI", show=False)
            pdf.savefig(fig); plt.close(fig)

            fig = plot_barplot_by_cell_type(mean_expr_by_ct, mean_expr_se_by_ct, 
                                            ctypes, w_ctype,
                                            title=f"Gene expression for {gene}",
                                            ylabel="Mean expression (normalized)", 
                                            show=False)
            pdf.savefig(fig); plt.close(fig)

            fig = plot_ME_vs_PSI(mod_eig, exon_psi,
                                 title=f"{w_ctype} ME vs. PSI for {gene} {exon_label} exon\nCorr: {corr}",
                                 show=False)
            pdf.savefig(fig); plt.close(fig)

            fig = violin_with_points(psi_vals_by_ct, ctypes, focus=w_ctype,
                                     ylabel="PSI",
                                     title=f"PSI distribution for {gene} {exon_label} exon",
                                     jitter=0.2, max_points_per_ct=3000, violin_alpha=0.2, 
                                     show=False)
            pdf.savefig(fig); plt.close(fig)
            
            fig = violin_with_points(expr_vals_by_ct, ctypes, focus=w_ctype,
                                     ylabel="Expression (log2)",
                                     title=f"Count distribution for {gene}",
                                     jitter=0.2, max_points_per_ct=3000, violin_alpha=0.2, 
                                     show=False)
            pdf.savefig(fig); plt.close(fig)

        print("Saved", exon)
        print("")
# Out:
# Astro
# Saved ENSMUSG00000027574_ProteinCoding_1
#
# Saved ENSMUSG00000032076_ProteinCoding_2
#
# Saved ENSMUSG00000032076_ProteinCoding_1
#
# Saved ENSMUSG00000066456_ProteinCoding_1
#
# Saved ENSMUSG00000031342_ProteinCoding_2
#
# Saved ENSMUSG00000022564_ProteinCoding_3
#
# Saved ENSMUSG00000024302_ProteinCoding_1
#
# Saved ENSMUSG00000040407_ProteinCoding_1
#
# Saved ENSMUSG00000037697_ProteinCoding_1
#
# Saved ENSMUSG00000053332_other_32
#
# Saved ENSMUSG00000033981_NMD_1
#
# Saved ENSMUSG00000039178_NMD_1
#
# Saved ENSMUSG00000022253_ProteinCoding_2
#
# Saved ENSMUSG00000047454_ProteinCoding_1
#
# Saved ENSMUSG00000005871_ProteinCoding_1
#
# Endo
# Saved ENSMUSG00000025085_ProteinCoding_2
#
# Saved ENSMUSG00000037936_ProteinCoding_1
#
# Saved ENSMUSG00000035863_ProteinCoding_1
#
# Saved ENSMUSG00000025085_ProteinCoding_1
#
# Saved ENSMUSG00000011958_ProteinCoding_1
#
# Saved ENSMUSG00000025006_ProteinCoding_8
#
# Saved ENSMUSG00000028559_ProteinCoding_1
#
# Saved ENSMUSG00000028613_ProteinCoding_5
#
# Saved ENSMUSG00000002504_ProteinCoding_1
#
# Saved ENSMUSG00000040242_ProteinCoding_2
#
# Saved ENSMUSG00000041890_ProteinCoding_1
#
# Saved ENSMUSG00000036817_ProteinCoding_3
#
# Saved ENSMUSG00000026159_ProteinCoding_1
#
# Saved ENSMUSG00000030782_ProteinCoding_1
#
# Saved ENSMUSG00000026566_ProteinCoding_1
#
# Macrophage
# Saved ENSMUSG00000024397_ProteinCoding_1
#
# Saved ENSMUSG00000018774_ProteinCoding_1
#
# Saved ENSMUSG00000018774_ProteinCoding_2
#
# Saved ENSMUSG00000020376_ProteinCoding_1
#
# Saved ENSMUSG00000006611_ProteinCoding_2
#
# Saved ENSMUSG00000004631_ProteinCoding_3
#
# Saved ENSMUSG00000017760_ProteinCoding_1
#
# Saved ENSMUSG00000017760_ProteinCoding_2
#
# Saved ENSMUSG00000040407_ProteinCoding_1
#
# Saved ENSMUSG00000033192_ProteinCoding_1
#
# Saved ENSMUSG00000000326_ProteinCoding_1
#
# Saved ENSMUSG00000017760_ProteinCoding_3
#
# Saved ENSMUSG00000030805_ProteinCoding_2
#
# Saved ENSMUSG00000011958_ProteinCoding_1
#
# Saved ENSMUSG00000024097_NMD_1
#
# Oligo
# Saved ENSMUSG00000041607_ProteinCoding_4
#
# Saved ENSMUSG00000041607_ProteinCoding_7
#
# Saved ENSMUSG00000024044_ProteinCoding_6
#
# Saved ENSMUSG00000033904_ProteinCoding_1
#
# Saved ENSMUSG00000031342_ProteinCoding_2
#
# Saved ENSMUSG00000020486_ProteinCoding_4
#
# Saved ENSMUSG00000069601_ProteinCoding_3
#
# Saved ENSMUSG00000038608_ProteinCoding_3
#
# Saved ENSMUSG00000022044_ProteinCoding_3
#
# Saved ENSMUSG00000019647_ProteinCoding_2
#
# Saved ENSMUSG00000052151_ProteinCoding_2
#
# Saved ENSMUSG00000033577_ProteinCoding_6
#
# Saved ENSMUSG00000035901_ProteinCoding_1
#
# Saved ENSMUSG00000024044_ProteinCoding_7
#
# Saved ENSMUSG00000033577_ProteinCoding_4
#
# VLMC
# Saved ENSMUSG00000004631_ProteinCoding_3
#
# Saved ENSMUSG00000001507_ProteinCoding_1
#
# Saved ENSMUSG00000025935_ProteinCoding_1
#
# Saved ENSMUSG00000031516_ProteinCoding_4
#
# Saved ENSMUSG00000027620_NMD_8
#
# Saved ENSMUSG00000097462_other_5
#
# Saved ENSMUSG00000030805_ProteinCoding_2
#
# Saved ENSMUSG00000039375_ProteinCoding_3
#
# Saved ENSMUSG00000035597_NMD_2
#
# Saved ENSMUSG00000029767_NMD_1
#
# Saved ENSMUSG00000024097_NMD_1
#
# Saved ENSMUSG00000035597_ProteinCoding_1
#
# Saved ENSMUSG00000067786_ProteinCoding_4
#
# Saved ENSMUSG00000033543_ProteinCoding_3
#
# Saved ENSMUSG00000112430_other_1
#
# Pvalb
# Saved ENSMUSG00000026797_ProteinCoding_1
#
# Saved ENSMUSG00000020436_ProteinCoding_1
#
# Saved ENSMUSG00000059534_other_1
#
# Saved ENSMUSG00000090841_ProteinCoding_3
#
# Saved ENSMUSG00000068739_ProteinCoding_1
#
# Saved ENSMUSG00000026825_ProteinCoding_1
#
# Saved ENSMUSG00000027634_ProteinCoding_1
#
# Saved ENSMUSG00000047126_ProteinCoding_1
#
# Saved ENSMUSG00000033530_other_1
#
# Saved ENSMUSG00000030616_ProteinCoding_1
#
# Saved ENSMUSG00000025871_ProteinCoding_5
#
# Saved ENSMUSG00000025871_ProteinCoding_4
#
# Saved ENSMUSG00000025290_ProteinCoding_1
#
# Saved ENSMUSG00000054423_ProteinCoding_5
#
# Saved ENSMUSG00000031078_ProteinCoding_2
#
# SMC
# Saved ENSMUSG00000032366_ProteinCoding_7
#
# Saved ENSMUSG00000025006_ProteinCoding_1
#
# Saved ENSMUSG00000030782_ProteinCoding_1
#
# Saved ENSMUSG00000025290_ProteinCoding_1
#
# Saved ENSMUSG00000024074_ProteinCoding_2
#
# Saved ENSMUSG00000029761_ProteinCoding_4
#
# Saved ENSMUSG00000029761_ProteinCoding_5
#
# Saved ENSMUSG00000005417_ProteinCoding_3
#
# Saved ENSMUSG00000029761_ProteinCoding_2
#
# Saved ENSMUSG00000025348_ProteinCoding_1
#
# Saved ENSMUSG00000031586_NMD_1
#
# Saved ENSMUSG00000026131_ProteinCoding_4
#
# Saved ENSMUSG00000042520_ProteinCoding_3
#
# Saved ENSMUSG00000028639_ProteinCoding_1
#
# Saved ENSMUSG00000025876_ProteinCoding_1
#
# Lamp5
# Saved ENSMUSG00000026670_ProteinCoding_2
#
# Saved ENSMUSG00000026670_ProteinCoding_1
#
# Saved ENSMUSG00000018395_ProteinCoding_2
#
# Saved ENSMUSG00000001911_ProteinCoding_1
#
# Saved ENSMUSG00000019907_ProteinCoding_2
#
# Saved ENSMUSG00000090063_other_2
#
# Saved ENSMUSG00000029422_ProteinCoding_1
#
# Saved ENSMUSG00000030616_ProteinCoding_1
#
# Saved ENSMUSG00000029422_ProteinCoding_3
#
# Saved ENSMUSG00000039953_ProteinCoding_1
#
# Saved ENSMUSG00000031644_ProteinCoding_4
#
# Saved ENSMUSG00000001986_NMD_1
#
# Saved ENSMUSG00000036873_NMD_1
#
# Saved ENSMUSG00000030689_ProteinCoding_2
#
# Saved ENSMUSG00000030689_other_1
#
# Sst
# Saved ENSMUSG00000026797_ProteinCoding_1
#
# Saved ENSMUSG00000026959_ProteinCoding_3
#
# Saved ENSMUSG00000054423_ProteinCoding_5
#
# Saved ENSMUSG00000014592_ProteinCoding_1
#
# Saved ENSMUSG00000026825_ProteinCoding_1
#
# Saved ENSMUSG00000053519_ProteinCoding_1
#
# Saved ENSMUSG00000027634_ProteinCoding_1
#
# Saved ENSMUSG00000040537_ProteinCoding_5
#
# Saved ENSMUSG00000009079_ProteinCoding_2
#
# Saved ENSMUSG00000068739_ProteinCoding_1
#
# Saved ENSMUSG00000057738_ProteinCoding_1
#
# Saved ENSMUSG00000039542_ProteinCoding_1
#
# Saved ENSMUSG00000028863_NMD_3
#
# Saved ENSMUSG00000033460_other_1
#
# Saved ENSMUSG00000031078_ProteinCoding_2
#
# Vip
# Saved ENSMUSG00000024617_ProteinCoding_1
#
# Saved ENSMUSG00000023092_ProteinCoding_2
#
# Saved ENSMUSG00000060424_other_9
#
# Saved ENSMUSG00000024109_ProteinCoding_1
#
# Saved ENSMUSG00000052726_ProteinCoding_6
#
# Saved ENSMUSG00000029757_ProteinCoding_2
#
# Saved ENSMUSG00000032076_ProteinCoding_3
#
# Saved ENSMUSG00000001911_ProteinCoding_1
#
# Saved ENSMUSG00000033768_ProteinCoding_8
#
# Saved ENSMUSG00000066392_ProteinCoding_4
#
# Saved ENSMUSG00000008140_ProteinCoding_1
#
# Saved ENSMUSG00000028399_ProteinCoding_4
#
# Saved ENSMUSG00000007888_ProteinCoding_2
#
# Saved ENSMUSG00000025468_ProteinCoding_1
#
# Saved ENSMUSG00000041658_ProteinCoding_1
#
# L5_IT
# Saved ENSMUSG00000032336_ProteinCoding_1
#
# Saved ENSMUSG00000052889_NMD_1
#
# Saved ENSMUSG00000015759_ProteinCoding_1
#
# Saved ENSMUSG00000003279_ProteinCoding_3
#
# Saved ENSMUSG00000063142_ProteinCoding_10
#
# Saved ENSMUSG00000027506_ProteinCoding_5
#
# Saved ENSMUSG00000031864_ProteinCoding_1
#
# Saved ENSMUSG00000028478_ProteinCoding_4
#
# Saved ENSMUSG00000024109_ProteinCoding_2
#
# Saved ENSMUSG00000021288_ProteinCoding_1
#
# Saved ENSMUSG00000045427_ProteinCoding_2
#
# Saved ENSMUSG00000023089_ProteinCoding_1
#
# Saved ENSMUSG00000022307_ProteinCoding_1
#
# Saved ENSMUSG00000027940_ProteinCoding_1
#
# Saved ENSMUSG00000039620_ProteinCoding_1
#
# NP
# Saved ENSMUSG00000013033_ProteinCoding_1
#
# Saved ENSMUSG00000037032_ProteinCoding_6
#
# Saved ENSMUSG00000036617_ProteinCoding_1
#
# Saved ENSMUSG00000028759_ProteinCoding_2
#
# Saved ENSMUSG00000029173_ProteinCoding_1
#
# Saved ENSMUSG00000021268_other_7
#
# Saved ENSMUSG00000025935_ProteinCoding_1
#
# Saved ENSMUSG00000027797_ProteinCoding_1
#
# Saved ENSMUSG00000020176_ProteinCoding_2
#
# Saved ENSMUSG00000026482_ProteinCoding_1
#
# Saved ENSMUSG00000059474_other_1
#
# Saved ENSMUSG00000097589_other_3
#
# Saved ENSMUSG00000028760_ProteinCoding_1
#
# Saved ENSMUSG00000022865_NMD_1
#
# Saved ENSMUSG00000006611_ProteinCoding_2
#
# L6_CT
# Saved ENSMUSG00000034813_ProteinCoding_2
#
# Saved ENSMUSG00000006673_ProteinCoding_5
#
# Saved ENSMUSG00000013539_ProteinCoding_2
#
# Saved ENSMUSG00000029471_ProteinCoding_1
#
# Saved ENSMUSG00000008658_ProteinCoding_2
#
# Saved ENSMUSG00000061751_ProteinCoding_1
#
# Saved ENSMUSG00000040374_ProteinCoding_1
#
# Saved ENSMUSG00000097462_other_4
#
# Saved ENSMUSG00000040964_ProteinCoding_1
#
# Saved ENSMUSG00000116295_other_2
#
# Saved ENSMUSG00000074217_ProteinCoding_1
#
# Saved ENSMUSG00000018501_ProteinCoding_2
#
# Saved ENSMUSG00000039826_ProteinCoding_1
#
# Saved ENSMUSG00000074867_ProteinCoding_1
#
# Saved ENSMUSG00000027574_ProteinCoding_1
#
# Peri
# Saved ENSMUSG00000105516_other_1
#
# Saved ENSMUSG00000068966_ProteinCoding_1
#
# Saved ENSMUSG00000108801_other_1
#
# Saved ENSMUSG00000050619_ProteinCoding_2
#
# Saved ENSMUSG00000068263_ProteinCoding_2
#
# Saved ENSMUSG00000032253_NMD_1
#
# Saved ENSMUSG00000060373_ProteinCoding_1
#
# Saved ENSMUSG00000064302_ProteinCoding_3
#
# Saved ENSMUSG00000024187_ProteinCoding_4
#
# Saved ENSMUSG00000027620_NMD_6
#
# Saved ENSMUSG00000027620_NMD_8
#
# Saved ENSMUSG00000070315_other_1
#
# Saved ENSMUSG00000024187_ProteinCoding_3
#
# Saved ENSMUSG00000040537_ProteinCoding_2
#
# Saved ENSMUSG00000060373_ProteinCoding_3
#
# L2_3_IT
# Saved ENSMUSG00000032336_ProteinCoding_1
#
# Saved ENSMUSG00000052889_NMD_1
#
# Saved ENSMUSG00000015759_ProteinCoding_1
#
# Saved ENSMUSG00000023089_ProteinCoding_1
#
# Saved ENSMUSG00000031864_ProteinCoding_1
#
# Saved ENSMUSG00000003279_ProteinCoding_3
#
# Saved ENSMUSG00000063142_ProteinCoding_10
#
# Saved ENSMUSG00000028478_ProteinCoding_4
#
# Saved ENSMUSG00000045427_ProteinCoding_2
#
# Saved ENSMUSG00000054423_other_2
#
# Saved ENSMUSG00000029095_ProteinCoding_1
#
# Saved ENSMUSG00000041351_ProteinCoding_2
#
# Saved ENSMUSG00000024109_ProteinCoding_2
#
# Saved ENSMUSG00000021288_ProteinCoding_1
#
# Saved ENSMUSG00000029095_ProteinCoding_3
#
# L6_IT
# Saved ENSMUSG00000052889_NMD_1
#
# Saved ENSMUSG00000032336_ProteinCoding_1
#
# Saved ENSMUSG00000015759_ProteinCoding_1
#
# Saved ENSMUSG00000023089_ProteinCoding_1
#
# Saved ENSMUSG00000063142_ProteinCoding_10
#
# Saved ENSMUSG00000028478_ProteinCoding_4
#
# Saved ENSMUSG00000021288_ProteinCoding_1
#
# Saved ENSMUSG00000041351_ProteinCoding_2
#
# Saved ENSMUSG00000036564_ProteinCoding_2
#
# Saved ENSMUSG00000045427_ProteinCoding_2
#
# Saved ENSMUSG00000003279_ProteinCoding_3
#
# Saved ENSMUSG00000022370_ProteinCoding_1
#
# Saved ENSMUSG00000033287_NMD_1
#
# Saved ENSMUSG00000022307_ProteinCoding_1
#
# Saved ENSMUSG00000054423_other_2
#
# L5_PT
# Saved ENSMUSG00000070003_ProteinCoding_2
#
# Saved ENSMUSG00000028759_ProteinCoding_1
#
# Saved ENSMUSG00000020642_ProteinCoding_1
#
# Saved ENSMUSG00000043251_NMD_1
#
# Saved ENSMUSG00000015127_ProteinCoding_1
#
# Saved ENSMUSG00000043251_ProteinCoding_2
#
# Saved ENSMUSG00000028759_ProteinCoding_2
#
# Saved ENSMUSG00000085067_other_1
#
# Saved ENSMUSG00000030538_ProteinCoding_1
#
# Saved ENSMUSG00000057265_ProteinCoding_1
#
# Saved ENSMUSG00000026098_ProteinCoding_1
#
# Saved ENSMUSG00000033111_ProteinCoding_1
#
# Saved ENSMUSG00000021018_ProteinCoding_1
#
# Saved ENSMUSG00000029616_ProteinCoding_1
#
# Saved ENSMUSG00000097303_other_1
#
# Sncg
# Saved ENSMUSG00000024617_ProteinCoding_1
#
# Saved ENSMUSG00000024109_ProteinCoding_1
#
# Saved ENSMUSG00000001911_ProteinCoding_1
#
# Saved ENSMUSG00000023092_ProteinCoding_2
#
# Saved ENSMUSG00000060424_other_9
#
# Saved ENSMUSG00000052726_ProteinCoding_6
#
# Saved ENSMUSG00000018395_ProteinCoding_2
#
# Saved ENSMUSG00000032076_ProteinCoding_3
#
# Saved ENSMUSG00000066392_ProteinCoding_4
#
# Saved ENSMUSG00000008140_ProteinCoding_1
#
# Saved ENSMUSG00000048004_ProteinCoding_1
#
# Saved ENSMUSG00000054728_ProteinCoding_1
#
# Saved ENSMUSG00000033768_ProteinCoding_8
#
# Saved ENSMUSG00000025468_ProteinCoding_1
#
# Saved ENSMUSG00000041658_ProteinCoding_1
#
# Serpinf1
# Saved ENSMUSG00000024617_ProteinCoding_1
#
# Saved ENSMUSG00000024109_ProteinCoding_1
#
# Saved ENSMUSG00000060424_other_9
#
# Saved ENSMUSG00000023092_ProteinCoding_2
#
# Saved ENSMUSG00000001911_ProteinCoding_1
#
# Saved ENSMUSG00000066392_ProteinCoding_4
#
# Saved ENSMUSG00000018395_ProteinCoding_2
#
# Saved ENSMUSG00000032076_ProteinCoding_3
#
# Saved ENSMUSG00000052726_ProteinCoding_6
#
# Saved ENSMUSG00000008140_ProteinCoding_1
#
# Saved ENSMUSG00000041658_ProteinCoding_1
#
# Saved ENSMUSG00000025468_ProteinCoding_1
#
# Saved ENSMUSG00000029757_ProteinCoding_2
#
# Saved ENSMUSG00000034341_ProteinCoding_1
#
# Saved ENSMUSG00000054728_ProteinCoding_1
#
# L6b
# Saved ENSMUSG00000053519_ProteinCoding_1
#
# Saved ENSMUSG00000026150_ProteinCoding_7
#
# Saved ENSMUSG00000039449_other_1
#
# Saved ENSMUSG00000024109_ProteinCoding_3
#
# Saved ENSMUSG00000026150_ProteinCoding_5
#
# Saved ENSMUSG00000066392_ProteinCoding_2
#
# Saved ENSMUSG00000033460_other_1
#
# Saved ENSMUSG00000033460_ProteinCoding_2
#
# Saved ENSMUSG00000022307_ProteinCoding_3
#
# Saved ENSMUSG00000033460_other_2
#
# Saved ENSMUSG00000037062_ProteinCoding_3
#
# Saved ENSMUSG00000033460_ProteinCoding_3
#
# Saved ENSMUSG00000073468_other_1
#
# Saved ENSMUSG00000028649_ProteinCoding_3
#
# Saved ENSMUSG00000036564_ProteinCoding_2
#
# Meis2
# Saved ENSMUSG00000030616_ProteinCoding_1
#
# Saved ENSMUSG00000026670_ProteinCoding_1
#
# Saved ENSMUSG00000026670_ProteinCoding_2
#
# Saved ENSMUSG00000020436_ProteinCoding_1
#
# Saved ENSMUSG00000054423_ProteinCoding_1
#
# Saved ENSMUSG00000019907_ProteinCoding_2
#
# Saved ENSMUSG00000026825_ProteinCoding_1
#
# Saved ENSMUSG00000034341_ProteinCoding_1
#
# Saved ENSMUSG00000054728_ProteinCoding_1
#
# Saved ENSMUSG00000040537_ProteinCoding_5
#
# Saved ENSMUSG00000001323_ProteinCoding_4
#
# Saved ENSMUSG00000009079_ProteinCoding_2
#
# Saved ENSMUSG00000047126_ProteinCoding_1
#
# Saved ENSMUSG00000014592_ProteinCoding_1
#
# Saved ENSMUSG00000041199_ProteinCoding_1
#
# CR
# Saved ENSMUSG00000024617_ProteinCoding_1
#
# Saved ENSMUSG00000024109_ProteinCoding_1
#
# Saved ENSMUSG00000066392_ProteinCoding_4
#
# Saved ENSMUSG00000018395_ProteinCoding_2
#
# Saved ENSMUSG00000001911_ProteinCoding_1
#
# Saved ENSMUSG00000041658_ProteinCoding_1
#
# Saved ENSMUSG00000060424_other_9
#
# Saved ENSMUSG00000034341_ProteinCoding_1
#
# Saved ENSMUSG00000019907_ProteinCoding_2
#
# Saved ENSMUSG00000023092_ProteinCoding_2
#
# Saved ENSMUSG00000001323_ProteinCoding_4
#
# Saved ENSMUSG00000032076_ProteinCoding_3
#
# Saved ENSMUSG00000090841_ProteinCoding_3
#
# Saved ENSMUSG00000054728_ProteinCoding_1
#
# Saved ENSMUSG00000026825_ProteinCoding_1
#
# L4
# Saved ENSMUSG00000024109_ProteinCoding_1
#
# Saved ENSMUSG00000001323_ProteinCoding_4
#
# Saved ENSMUSG00000024617_ProteinCoding_1
#
# Saved ENSMUSG00000037400_NMD_1
#
# Saved ENSMUSG00000056167_ProteinCoding_3
#
# Saved ENSMUSG00000025468_ProteinCoding_1
#
# Saved ENSMUSG00000054423_ProteinCoding_1
#
# Saved ENSMUSG00000022744_other_1
#
# Saved ENSMUSG00000018395_ProteinCoding_2
#
# Saved ENSMUSG00000054728_ProteinCoding_1
#
# Saved ENSMUSG00000066392_ProteinCoding_4
#
# Saved ENSMUSG00000031078_ProteinCoding_2
#
# Saved ENSMUSG00000026825_ProteinCoding_1
#
# Saved ENSMUSG00000001911_ProteinCoding_1
#
# Saved ENSMUSG00000015214_ProteinCoding_6
