# %%
setwd("/mnt/lareaulab/reliscu/projects/NSF_GRFP/analyses/pseudobulk_test/tasic_2018/mouse_ALM")

source("code/enrichment_fxns.R")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last

# %%
mod_def <- "PosBC"
unique <- TRUE
lfc_threshold <- 5

# %%
pairwise_res_list <- readRDS("data/tasic_2018_ALM_STAR_donor_cell_type_pseudobulk_pairwise_DE_genes_dream.RDS")
pairwise_res_list <- pairwise_res_list[!grepl("L4|Peri",  names(pairwise_res_list))]
pairwise_ctype_genes <- prep_DE_genes(pairwise_res_list, lfc_threshold, pairwise=TRUE, unique=unique)

# %%
for (i in 1:length(pairwise_ctype_genes)) {
    w_list <- pairwise_ctype_genes[[i]]
    write.csv(data.frame(Gene=w_list), file=paste0("pairwise_DE_genes_unique/", names(pairwise_ctype_genes)[i] ,".csv"), row.names=FALSE)
}
